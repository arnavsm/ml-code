# %% [markdown]
# # Introducing Pandas

# %% [markdown]
# # Installing & Importing Pandas

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# # Loading the Data Set

# %%
#Reading the file
data = pd.read_csv("world_happiness_report.csv")
# sep = ';' index_col = "Country",

# %% [markdown]
# # The Two Objects in Pandas: Series & Dataframe

# %%
pd.Series([1,2,3,4], index = [100,101,102,104], name = "MyData")
# Out:
# 100    1
# 101    2
# 102    3
# 104    4
# Name: MyData, dtype: int64

# %%
pd.DataFrame({'A': [100,101,102,103], 'B': [0,1,2,3]}, index = ['W', 'X', 'Y', 'Z'])
# Out:
#      A  B
# W  100  0
# X  101  1
# Y  102  2
# Z  103  3

# %% [markdown]
# # Basic DataFrame Operations

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data.sample()
# Out:
#     Country                           Region  Happiness Rank  Happiness Score  \
# 119   Egypt  Middle East and Northern Africa             120            4.362
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# 119                      4.259                      4.465
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 119                   0.95395  0.49813                   0.52116  0.18847
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 119                        0.10393     0.12706            1.96895

# %%
data.sample(5)
# Out:
#         Country                           Region  Happiness Rank  \
# 75      Somalia               Sub-Saharan Africa              76
# 149     Liberia               Sub-Saharan Africa             150
# 37      Algeria  Middle East and Northern Africa              38
# 140      Angola               Sub-Saharan Africa             141
# 13   Costa Rica      Latin America and Caribbean              14
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 75             5.440                      5.321                      5.559
# 149            3.622                      3.463                      3.781
# 37             6.355                      6.227                      6.483
# 140            3.866                      3.753                      3.979
# 13             7.087                      6.999                      7.175
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
data.Freedom.describe()
# Out:
# count    157.000000
# mean       0.370994
# std        0.145507
# min        0.000000
# 25%        0.257480
# 50%        0.397470
# 75%        0.484530
# max        0.608480
# Name: Freedom, dtype: float64

# %%
data.shape
# Out:
# (157, 13)

# %%
data.corr()
# Out:
# C:\Users\arnav\AppData\Local\Temp\ipykernel_10980\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                Happiness_Rank  Happiness_Score  \
# Happiness_Rank                       1.000000        -0.995743
# Happiness_Score                     -0.995743         1.000000
# Lower_Confidence_Interval           -0.994928         0.999485
# Upper_Confidence_Interval           -0.995525         0.999474
# Economy_(GDP_per_Capita)            -0.793577         0.790322
# Family                              -0.733276         0.739252
# Health_(Life_Expectancy)            -0.767991         0.765384
# Freedom                             -0.557169         0.566827
# Trust_(Government_Corruption)       -0.387102         0.402032
# ...

# %%
data.set_index("Country")
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Denmark                       Western Europe               1            7.526
# Switzerland                   Western Europe               2            7.509
# Iceland                       Western Europe               3            7.501
# Norway                        Western Europe               4            7.498
# Finland                       Western Europe               5            7.413
# ...                                      ...             ...              ...
# Benin                     Sub-Saharan Africa             153            3.484
# Afghanistan                    Southern Asia             154            3.360
# Togo                      Sub-Saharan Africa             155            3.303
# Syria        Middle East and Northern Africa             156            3.069
# Burundi                   Sub-Saharan Africa             157            2.905
#
# ...

# %%
data_copy = data.copy()

# %% [markdown]
# # Indexing & Selection of Different Columns & Rows

# %%
data.Country
# Out:
# 0          Denmark
# 1      Switzerland
# 2          Iceland
# 3           Norway
# 4          Finland
#           ...
# 152          Benin
# 153    Afghanistan
# 154           Togo
# 155          Syria
# 156        Burundi
# Name: Country, Length: 157, dtype: object

# %%
data["Country"]
# Out:
# 0          Denmark
# 1      Switzerland
# 2          Iceland
# 3           Norway
# 4          Finland
#           ...
# 152          Benin
# 153    Afghanistan
# 154           Togo
# 155          Syria
# 156        Burundi
# Name: Country, Length: 157, dtype: object

# %%
data[["Country", "Happiness Rank"]]
# Out:
#          Country  Happiness Rank
# 0        Denmark               1
# 1    Switzerland               2
# 2        Iceland               3
# 3         Norway               4
# 4        Finland               5
# ..           ...             ...
# 152        Benin             153
# 153  Afghanistan             154
# 154         Togo             155
# 155        Syria             156
# 156      Burundi             157
#
# [157 rows x 2 columns]

# %%
data["Country"][11]
# Out:
# 'Austria'

# %%
data.iloc[0]
# Out:
# Country                                 Denmark
# Region                           Western Europe
# Happiness Rank                                1
# Happiness Score                           7.526
# Lower Confidence Interval                  7.46
# Upper Confidence Interval                 7.592
# Economy (GDP per Capita)                1.44178
# Family                                  1.16374
# Health (Life Expectancy)                0.79504
# Freedom                                 0.57941
# Trust (Government Corruption)           0.44453
# Generosity                              0.36171
# Dystopia Residual                       2.73939
# Name: 0, dtype: object

# %%
data.iloc[:, 0]
# Out:
# 0          Denmark
# 1      Switzerland
# 2          Iceland
# 3           Norway
# 4          Finland
#           ...
# 152          Benin
# 153    Afghanistan
# 154           Togo
# 155          Syria
# 156        Burundi
# Name: Country, Length: 157, dtype: object

# %%
data.iloc[:10, 0]
# Out:
# 0        Denmark
# 1    Switzerland
# 2        Iceland
# 3         Norway
# 4        Finland
# 5         Canada
# 6    Netherlands
# 7    New Zealand
# 8      Australia
# 9         Sweden
# Name: Country, dtype: object

# %%
data.iloc[5:10, 0]
# Out:
# 5         Canada
# 6    Netherlands
# 7    New Zealand
# 8      Australia
# 9         Sweden
# Name: Country, dtype: object

# %%
data.iloc[-10:]
# Out:
#          Country                           Region  Happiness Rank  \
# 147   Madagascar               Sub-Saharan Africa             148
# 148     Tanzania               Sub-Saharan Africa             149
# 149      Liberia               Sub-Saharan Africa             150
# 150       Guinea               Sub-Saharan Africa             151
# 151       Rwanda               Sub-Saharan Africa             152
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 147            3.695                      3.621                      3.769
# 148            3.666                      3.561                      3.771
# ...

# %%
data.iloc[:, -3:]
# Out:
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.44453     0.36171            2.73939
# 1                          0.41203     0.28083            2.69463
# 2                          0.14975     0.47678            2.83137
# 3                          0.35776     0.37895            2.66465
# 4                          0.41004     0.25492            2.82596
# ..                             ...         ...                ...
# 152                        0.06681     0.20180            2.10812
# 153                        0.07112     0.31268            2.14558
# 154                        0.11587     0.17517            2.13540
# 155                        0.17233     0.48397            0.81789
# 156                        0.09419     0.20290            2.10404
#
# [157 rows x 3 columns]

# %%
data.loc[:5, ["Region","Family"]]
# Out:
#            Region   Family
# 0  Western Europe  1.16374
# 1  Western Europe  1.14524
# 2  Western Europe  1.18326
# 3  Western Europe  1.12690
# 4  Western Europe  1.13464
# 5   North America  1.09610

# %%
data.loc[data.Family > 0.5]
# data.loc[(data.Family > 0.5) & (data.Region == "Western Europe") ]
# instead of & we can use /.
# with ==,
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 0         Denmark      Western Europe               1            7.526
# 1     Switzerland      Western Europe               2            7.509
# 2         Iceland      Western Europe               3            7.501
# 3          Norway      Western Europe               4            7.498
# 4         Finland      Western Europe               5            7.413
# ..            ...                 ...             ...              ...
# 144  Burkina Faso  Sub-Saharan Africa             145            3.739
# 145        Uganda  Sub-Saharan Africa             145            3.739
# 148      Tanzania  Sub-Saharan Africa             149            3.666
# 149       Liberia  Sub-Saharan Africa             150            3.622
# 151        Rwanda  Sub-Saharan Africa             152            3.515
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# ...

# %%
data.loc[data.Region.isin(["North America", "Western Europe"])]
# Out:
#            Country          Region  Happiness Rank  Happiness Score  \
# 0          Denmark  Western Europe               1            7.526
# 1      Switzerland  Western Europe               2            7.509
# 2          Iceland  Western Europe               3            7.501
# 3           Norway  Western Europe               4            7.498
# 4          Finland  Western Europe               5            7.413
# 5           Canada   North America               6            7.404
# 6      Netherlands  Western Europe               7            7.339
# 9           Sweden  Western Europe              10            7.291
# 11         Austria  Western Europe              12            7.119
# 12   United States   North America              13            7.104
# 15         Germany  Western Europe              16            6.994
# 17         Belgium  Western Europe              18            6.929
# 18         Ireland  Western Europe              19            6.907
# ...

# %%
data.loc[data["Happiness Score"].notnull()]
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
data.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
data.Region.nunique()
# Out:
# 10

# %%
data.Region.value_counts()
# Out:
# Sub-Saharan Africa                 38
# Central and Eastern Europe         29
# Latin America and Caribbean        24
# Western Europe                     21
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # Data Cleaning & Preprocessing

# %%
data.rename(columns = {"Happiness Score": "Happiness_Score"})
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
data.columns = data.columns.str.replace(' ', '_') 
data
# Out:
#          Country                           Region  Happiness_Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
data.rename(index = {0: "Zero", 1: "One"})
# Out:
#           Country                           Region  Happiness_Rank  \
# Zero      Denmark                   Western Europe               1
# One   Switzerland                   Western Europe               2
# 2         Iceland                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4         Finland                   Western Europe               5
# ...           ...                              ...             ...
# 152         Benin               Sub-Saharan Africa             153
# 153   Afghanistan                    Southern Asia             154
# 154          Togo               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
#
#       Happiness_Score  Lower_Confidence_Interval  Upper_Confidence_Interval  \
# Zero            7.526                      7.460                      7.592
# ...

# %%
data.rename_axis("instances", axis='rows').rename_axis("features", axis='columns')
# Out:
# features       Country                           Region  Happiness_Rank  \
# instances
# 0              Denmark                   Western Europe               1
# 1          Switzerland                   Western Europe               2
# 2              Iceland                   Western Europe               3
# 3               Norway                   Western Europe               4
# 4              Finland                   Western Europe               5
# ...                ...                              ...             ...
# 152              Benin               Sub-Saharan Africa             153
# 153        Afghanistan                    Southern Asia             154
# 154               Togo               Sub-Saharan Africa             155
# 155              Syria  Middle East and Northern Africa             156
# 156            Burundi               Sub-Saharan Africa             157
#
# features   Happiness_Score  Lower_Confidence_Interval  \
# instances
# ...

# %%
data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness_Rank                     int64
# Happiness_Score                  float64
# Lower_Confidence_Interval        float64
# Upper_Confidence_Interval        float64
# Economy_(GDP_per_Capita)         float64
# Family                           float64
# Health_(Life_Expectancy)         float64
# Freedom                          float64
# Trust_(Government_Corruption)    float64
# Generosity                       float64
# Dystopia_Residual                float64
# dtype: object

# %%
data.Country.dtype
# Out:
# dtype('O')

# %%
data.Happiness_Rank.astype('float64')
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 152    153.0
# 153    154.0
# 154    155.0
# 155    156.0
# 156    157.0
# Name: Happiness_Rank, Length: 157, dtype: float64

# %%
data
# Out:
#          Country                           Region  Happiness_Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
data[pd.isnull(data.Family)]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness_Rank, Happiness_Score, Lower_Confidence_Interval, Upper_Confidence_Interval, Economy_(GDP_per_Capita), Family, Health_(Life_Expectancy), Freedom, Trust_(Government_Corruption), Generosity, Dystopia_Residual]
# Index: []

# %%
data.Family.fillna("Not Available") # or data.Family.mean()
# Out:
# 0      1.16374
# 1      1.14524
# 2      1.18326
# 3      1.12690
# 4      1.13464
#         ...
# 152    0.10419
# 153    0.11037
# 154    0.00000
# 155    0.14866
# 156    0.23442
# Name: Family, Length: 157, dtype: float64

# %%
data.isnull()
# Out:
#      Country  Region  Happiness_Rank  Happiness_Score  \
# 0      False   False           False            False
# 1      False   False           False            False
# 2      False   False           False            False
# 3      False   False           False            False
# 4      False   False           False            False
# ..       ...     ...             ...              ...
# 152    False   False           False            False
# 153    False   False           False            False
# 154    False   False           False            False
# 155    False   False           False            False
# 156    False   False           False            False
#
#      Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# ...

# %%
nan_cols = data.columns[data.isnull().any()]
data[nan_cols].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
data.isnull().any()
# Out:
# Country                          False
# Region                           False
# Happiness_Rank                   False
# Happiness_Score                  False
# Lower_Confidence_Interval        False
# Upper_Confidence_Interval        False
# Economy_(GDP_per_Capita)         False
# Family                           False
# Health_(Life_Expectancy)         False
# Freedom                          False
# Trust_(Government_Corruption)    False
# Dystopia_Residual                False
# dtype: bool

# %%
data.drop(['Generosity'], axis = 1, inplace = True)

# %%
data.Country.replace("Denmark", "DENMARK", inplace = True)

# %%
data
# Out:
#          Country                           Region  Happiness_Rank  \
# 0        DENMARK                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness_Score  Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0              7.526                      7.460                      7.592
# ...
